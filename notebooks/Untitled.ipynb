# %%
import json

# %%
d = json.load(open('../results/01282021_new/som_germ_cnv_pur_target_expression/results.json'))

# %%
d.keys()
# Out:
# dict_keys(['BR', 'CO', 'GBM', 'HNSCC', 'LSCC', 'LUAD', 'OV', 'PDA', 'UCEC', 'ccRCC'])

# %%
d['LSCC'].keys()
# Out:
# dict_keys(['ABL1_ABI1', 'ABL1_ABL1', 'ABL1_ABL2', 'ABL1_AHSA1', 'ABL1_ANXA1', 'ABL1_APBB1', 'ABL1_ATR', 'ABL1_BCAR1', 'ABL1_BCR', 'ABL1_BNIP2', 'ABL1_BOC', 'ABL1_BRCA1', 'ABL1_BTK', 'ABL1_CABLES1', 'ABL1_CABLES2', 'ABL1_CAP1', 'ABL1_CAP2', 'ABL1_CASP9', 'ABL1_CAT', 'ABL1_CAV1', 'ABL1_CD19', 'ABL1_CDC42', 'ABL1_CDC73', 'ABL1_CDH15', 'ABL1_CDH2', 'ABL1_CDH4', 'ABL1_CDK1', 'ABL1_CDK5', 'ABL1_CDKN1B', 'ABL1_CDON', 'ABL1_CEBPB', 'ABL1_CLASP1', 'ABL1_CLASP2', 'ABL1_CLK1', 'ABL1_CLK4', 'ABL1_CRK', 'ABL1_CRKL', 'ABL1_CTNNA1', 'ABL1_CTNNA2', 'ABL1_CTNNB1', 'ABL1_CTTN', 'ABL1_DDB2', 'ABL1_DDX5', 'ABL1_EGFR', 'ABL1_EMD', 'ABL1_ERCC6', 'ABL1_ESR1', 'ABL1_ESR2', 'ABL1_FOXA1', 'ABL1_FYN', 'ABL1_GPX1', 'ABL1_HCK', 'ABL1_HDAC2', 'ABL1_HIPK2', 'ABL1_HRAS', 'ABL1_JAK2', 'ABL1_JUN', 'ABL1_JUNB', 'ABL1_KAT5', 'ABL1_LASP1', 'ABL1_LATS2', 'ABL1_LGALS3', 'ABL1_LYN', 'ABL1_MAP3K8', 'ABL1_MAP4K1', 'ABL1_MAPK11', 'ABL1_MAPK12', 'ABL1_MAPK14', 'ABL1_MAPT', 'ABL1_MDM2', 'ABL1_MDM4', 'ABL1_MET', 'ABL1_MSH5', 'AB
# ...

# %%
d['LSCC']['ABL1_ABI1'].keys()
# Out:
# dict_keys(['coef_df', 'r-squared', 'r-squared p-value', 'groundtruth', 'predicted', 'features', 'X', 'y', 'r-squared FDR'])

# %%
import pandas as pd
pd.DataFrame(d['LSCC']['BRCA1_BABAM1']['X'])
# Out:
#              driver_gene_cnv  TumorPurity  driver_gene_has_nonsilent_mutation
# C3L-00081-T         1.140082     0.548148                                 0.0
# C3L-00415-T        -0.817570     0.453219                                 0.0
# C3L-00445-T         0.627555     0.485979                                 0.0
# C3L-00568-T        -0.304664    -0.796192                                 0.0
# C3L-00603-T         0.656688     0.462186                                 0.0
# ...                      ...          ...                                 ...
# C3N-03886-T         0.725889     1.637916                                 0.0
# C3N-04124-T         0.432213    -0.701544                                 1.0
# C3N-04127-T        -0.271991    -0.994208                                 0.0
# C3N-04155-T        -0.650035     1.480800                                 0.0
# C3N-04162-T         0.400867     1.294349                                 0.0
#
# [107 rows x 3 columns]
